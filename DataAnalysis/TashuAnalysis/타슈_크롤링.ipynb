# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import time
import re

# %%
# 크롤링 정보를 저장할 데이터프레임 선언
data = pd.DataFrame(columns=['스테이션명','위치','상태정보','위도','경도'])

# 크롤링 할 타슈 사이트 주소
url_tashu = 'http://www.tashu.or.kr/userStationAction.do?process=list'

# 페이지 이동 시 추가로 적어줘야 되는 url
url_add = '&page='

# 전체 페이지 수
total_page = 27

# 27 page에 대한 정보를 추출하는 for문
for index in range(1,total_page+1):
  if index ==1:
    url = url_tashu # 첫번째 페이지
  else:
    url = url_tashu + url_add + str(index) # 페이지 정보 추가

  # url에서 html 추출
  html = urlopen(url)

  # html을 파싱하여 데이터로 변환
  bsObject = BeautifulSoup(html, 'html.parser',from_encoding='utf-8') # html 이니까 html.parser로 파싱해줘

  # div 는 감싸고 있기 때문에 div 부분부터 접근해야함 but class 명이 있을경우 class로 접근해도됨
  # history_table 이라고 하는 class를 가진 table만 추출
  table = bsObject.find_all('table',{'class','history_table'}) # class의 history_table를 찾아서 table에 담음

  # table 내에서 tr 추출
  tr = table[0].find_all('tr')

  # 첫 tr은 contents가 아니라, 데이터 정보를 의미하기 때문에 제외
  tr = tr[1:len(tr)] # 갖고있는 tr 개수만큼만

  # 한페이지의 정보를 크롤링
  for index_tr in range(0,len(tr)):
    td = tr[index_tr].find_all('td')
    
    # 장소
    station = td[0].text.split('.')[1] # 1.무역전시관입구(택시승강장)

    # 위치
    location = td[1].text

    # 상태
    condition = td[2].text

    # 좌표추출
    geo = td[3].a.attrs['href'].split('(')[1] # '36.374580', '127.386131'); 추출

    # 위도, 경도 추출을 위한 데이터 클렌징
    geo = re.sub('[;)]','',geo)   # [:)] 없애라 -> '36.374580', '127.386131' 추출
    detail_location = geo.replace("'","")  # 작은따옴표(') 삭제 -> 36.374580, 127.386131

    # 위도 Latitude
    lat = detail_location.split(',')[0]

    # 경도 Longitude
    lon = detail_location.split(',')[1]

    # data에 크롤링 결과 저장 (딕셔너리 형태로 만들기)
    data = data.append({'스테이션명':station,
                        '위치':location,
                        '상태정보':condition,
                        '위도':lat,
                        '경도':lon},
                       ignore_index=True) # 인덱스 쓰지 않겠다
    print('Complete of' + str(index_tr+1) + 'information with' + str(index) + 'Page' )
  
  # Crawling 막히는 것 방지
  time.sleep(1)

print('-----------------------------------------------------------------------------')
print(data)
# Out:
# Complete of1information with1Page
# Complete of2information with1Page
# Complete of3information with1Page
# Complete of4information with1Page
# Complete of5information with1Page
# Complete of6information with1Page
# Complete of7information with1Page
# Complete of8information with1Page
# Complete of9information with1Page
# Complete of10information with1Page
# Complete of1information with2Page
# Complete of2information with2Page
# Complete of3information with2Page
# Complete of4information with2Page
# Complete of5information with2Page
# Complete of6information with2Page
# Complete of7information with2Page
# Complete of8information with2Page
# Complete of9information with2Page
# Complete of10information with2Page
# Complete of1information with3Page
# Complete of2information with3Page
# Complete of3information with3Page
# Complete of4information with3Page
# Complete of5information with3Page
# Complete of6information with3Page
# Complete of7information with3Page
# Complete of8information with3Page
# Complete of9information with3Page
# Complete of10information with3Page
# Complete of1information with4Page
# Complete of2information with4Page
# Complete of3information with4Page
# Complete of4information with4Page
# Complete of5information with4Page
# Complete of6information with4Page
# Complete of7information with4Page
# Complete of8information with4Page
# Complete of3information with18Page
# Complete of4information with18Page
# Complete of5information with18Page
# Complete of6information with18Page
# Complete of7information with18Page
# Complete of8information with18Page
# Complete of9information with18Page
# Complete of10information with18Page
# Complete of1information with19Page
# Complete of2information with19Page
# Complete of3information with19Page
# Complete of4information with19Page
# Complete of5information with19Page
# Complete of6information with19Page
# Complete of7information with19Page
# Complete of8information with19Page
# Complete of9information with19Page
# Complete of10information with19Page
# Complete of1information with20Page
# Complete of2information with20Page
# Complete of3information with20Page
# Complete of4information with20Page
# Complete of5information with20Page
# Complete of6information with20Page
# Complete of7information with20Page
# Complete of8information with20Page
# Complete of9information with20Page
# Complete of10information with20Page
# Complete of1information with21Page
# Complete of2information with21Page
# Complete of3information with21Page
# Complete of4information with21Page
# Complete of5information with21Page
# Complete of6information with21Page
# Complete of7information with21Page
# Complete of8information with21Page
# Complete of9information with21Page
# Complete of10information with21Page
# Complete of1information with22Page
# Complete of2information with22Page
# Complete of3information with22Page
# Complete of4information with22Page
# Complete of5information with22Page
# Complete of6information with22Page
# Complete of7information with22Page
# Complete of8information with22Page
# Complete of9information with22Page
# Complete of10information with22Page
# Complete of1information with23Page
# Complete of2information with23Page
# Complete of3information with23Page
# Complete of4information with23Page
# Complete of5information with23Page
# Complete of6information with23Page
# Complete of7information with23Page
# Complete of8information with23Page
# Complete of9information with23Page
# Complete of10information with23Page
# Complete of1information with24Page
# Complete of2information with24Page
# Complete of3information with24Page
# Complete of4information with24Page
# Complete of5information with24Page
# Complete of6information with24Page
# Complete of7information with24Page
# Complete of8information with24Page
# Complete of9information with24Page
# Complete of10information with24Page
# Complete of1information with25Page
# Complete of2information with25Page
# Complete of3information with25Page
# Complete of4information with25Page
# Complete of5information with25Page
# Complete of6information with25Page
# Complete of7information with25Page
# Complete of8information with25Page
# Complete of9information with25Page
# Complete of10information with25Page
# Complete of1information with26Page
# Complete of2information with26Page
# Complete of3information with26Page
# Complete of4information with26Page
# Complete of5information with26Page
# Complete of6information with26Page
# Complete of7information with26Page
# Complete of8information with26Page
# Complete of9information with26Page
# Complete of10information with26Page
# Complete of1information with27Page
# Complete of2information with27Page
# -----------------------------------------------------------------------------
#                  스테이션명                 위치 상태정보         위도           경도
# 0       무역전시관입구(택시승강장)       유성구 도룡동 3-8    정상  36.374580   127.386131
# 1              대전컨벤션센터      유성구 도룡동 4-19    정상  36.374389   127.392375
# 2               한밭수목원1        서구 만년동 396    정상  36.368995   127.388451
# 3    초원아파트(104동 버스정류장)        서구 만년동 401    정상  36.367945   127.379302
# 4      둔산대공원 입구(버스정류장)   서구 둔산2동 1521-10    정상  36.364974   127.388856
# ..                 ...                ...  ...        ...          ...
# 257              천문대입구       유성구 신성동 458    정상  36.382848   127.355004
# 258              대덕대학교         유성구 장동 48    정상  36.390462   127.362420
# 259        오정농수산물 도매시장      대덕구 오정동 45-1    정상  36.357693   127.407763
# 260   도로교통공단(건너편 라도무스)      유성구 원신흥동 608    정상  36.332692   127.333128
# 261              반석 더샵       유성구 반석동 704    정상  36.390096   127.305095
#
# [262 rows x 5 columns]

# %% [markdown]
# 크롤링 저장하기

# %%
data.to_csv('TASHU.csv',encoding='utf-8-sig')
