# %%
from tensorflow.keras.datasets.fashion_mnist import load_data

# 텐서플로우 저장소에서 데이터를 다운받습니다.
(x_train, y_train), (x_test, y_test) = load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
print(x_train.shape, x_test.shape)
# Out:
# (60000, 28, 28) (10000, 28, 28)

# %% [markdown]
# 데이터 그려보기

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(777)

# Fashion-MNIST의 레이블에 해당하는 품목입니다.
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

sample_size = 9
# 0 ~ 59999의 범위에서 무작위로 9개의 정수를 뽑습니다.
random_idx = np.random.randint(60000, size=sample_size) 

plt.figure(figsize = (5, 5))
for i, idx in enumerate(random_idx):
    plt.subplot(3, 3, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[i], cmap = 'gray')
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %% [markdown]
# 전처리 및 검증 데이터셋 만들기

# %%
# 값의 범위를 0 ~ 1 사이로 만들기 -> 스케일링 -> minmax 알고리즘

x_train = x_train / 255
x_test = x_test / 255

print(x_train[0])

# %%
# 레이블 (정답지) 범주형 데이터로 변경
from tensorflow.keras.utils import to_categorical

# 실제 정답 비교를 위해 0-9 정답지 따로 저장
real_y_test = y_test

# 각 데이터의 레이블을 범주형 형태로 변경
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
# 검증 데이터 세트 만들기
from sklearn.model_selection import train_test_split

# 훈련/검증 데이터를 7:3 비율로 분리
x_train, x_val, y_train, y_val = train_test_split(x_train,y_train,
                                                  test_size=0.3,
                                                  random_state=777)

# %% [markdown]
# 첫 번째 모델 구성하기

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

first_model = Sequential()

first_model.add(Flatten(input_shape=(28,28)))
#Flatten(28, 28)함수 -> .(28 * 28) -> 1차원 784로 변환

first_model.add(Dense(64, activation='relu'))
first_model.add(Dense(32, activation='relu'))
first_model.add(Dense(10, activation='softmax'))

# %% [markdown]
# 첫 번째 모델 설정하기

# %%
first_model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %% [markdown]
# 첫 번째 모델 학습하기

# %%
first_history = first_model.fit(x_train, y_train,
                    epochs=30,
                    batch_size=128,
                    validation_data=(x_val,y_val)) # batch_size 64번 공부해라
                    # validation 쪽지시험 결과도 나옴
# Out:
# Epoch 1/30
# 329/329 [==============================] - 3s 6ms/step - loss: 0.6657 - accuracy: 0.7745 - val_loss: 0.4859 - val_accuracy: 0.8277
# Epoch 2/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4346 - accuracy: 0.8461 - val_loss: 0.4275 - val_accuracy: 0.8489
# Epoch 3/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3968 - accuracy: 0.8580 - val_loss: 0.3972 - val_accuracy: 0.8606
# Epoch 4/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3724 - accuracy: 0.8670 - val_loss: 0.3786 - val_accuracy: 0.8662
# Epoch 5/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3490 - accuracy: 0.8734 - val_loss: 0.3891 - val_accuracy: 0.8614
# Epoch 6/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3325 - accuracy: 0.8797 - val_loss: 0.3677 - val_accuracy: 0.8701
# Epoch 7/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3204 - accuracy: 0.8840 - val_loss: 0.3653 - val_accuracy: 0.8682
# Epoch 8/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3051 - accuracy: 0.8879 - val_loss: 0.3493 - val_accuracy: 0.8754
# Epoch 9/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2956 - accuracy: 0.8916 - val_loss: 0.3286 - val_accuracy: 0.8852
# Epoch 10/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2854 - accuracy: 0.8941 - val_loss: 0.3281 - val_accuracy: 0.8817
# Epoch 11/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2808 - accuracy: 0.8977 - val_loss: 0.3439 - val_accuracy: 0.8808
# Epoch 12/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2706 - accuracy: 0.9009 - val_loss: 0.3313 - val_accuracy: 0.8833
# Epoch 13/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2664 - accuracy: 0.9015 - val_loss: 0.3289 - val_accuracy: 0.8843
# Epoch 14/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2605 - accuracy: 0.9037 - val_loss: 0.3232 - val_accuracy: 0.8874
# Epoch 15/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2521 - accuracy: 0.9067 - val_loss: 0.3249 - val_accuracy: 0.8845
# Epoch 16/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2456 - accuracy: 0.9080 - val_loss: 0.3233 - val_accuracy: 0.8884
# Epoch 17/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2450 - accuracy: 0.9088 - val_loss: 0.3420 - val_accuracy: 0.8805
# Epoch 18/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2382 - accuracy: 0.9120 - val_loss: 0.3368 - val_accuracy: 0.8830
# Epoch 19/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2307 - accuracy: 0.9144 - val_loss: 0.3276 - val_accuracy: 0.8906
# Epoch 20/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2267 - accuracy: 0.9151 - val_loss: 0.3371 - val_accuracy: 0.8823
# Epoch 21/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2222 - accuracy: 0.9177 - val_loss: 0.3360 - val_accuracy: 0.8858
# Epoch 22/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2203 - accuracy: 0.9174 - val_loss: 0.3310 - val_accuracy: 0.8877
# Epoch 23/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2098 - accuracy: 0.9215 - val_loss: 0.3456 - val_accuracy: 0.8846
# Epoch 24/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2078 - accuracy: 0.9232 - val_loss: 0.3436 - val_accuracy: 0.8845
# Epoch 25/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2062 - accuracy: 0.9224 - val_loss: 0.3371 - val_accuracy: 0.8894
# Epoch 26/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2000 - accuracy: 0.9263 - val_loss: 0.3259 - val_accuracy: 0.8911
# Epoch 27/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2007 - accuracy: 0.9251 - val_loss: 0.3323 - val_accuracy: 0.8912
# Epoch 28/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1925 - accuracy: 0.9288 - val_loss: 0.3346 - val_accuracy: 0.8902
# Epoch 29/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1906 - accuracy: 0.9295 - val_loss: 0.3521 - val_accuracy: 0.8908
# Epoch 30/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1884 - accuracy: 0.9300 - val_loss: 0.3612 - val_accuracy: 0.8852

# %% [markdown]
# 두 번째 모델 설정하기

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

second_model = Sequential()

second_model.add(Flatten(input_shape=(28,28)))
#Flatten(28, 28)함수 -> .(28 * 28) -> 1차원 784로 변환

second_model.add(Dense(64, activation='relu'))
second_model.add(Dense(32, activation='relu'))
second_model.add(Dense(10, activation='softmax'))

second_model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

second_history = second_model.fit(x_train, y_train,
                    epochs=30,
                    batch_size=128,
                    validation_data=(x_val,y_val)) # batch_size 64번 공부해라
                    # validation 쪽지시험 결과도 나옴
# Out:
# Epoch 1/30
# 329/329 [==============================] - 2s 5ms/step - loss: 0.6580 - accuracy: 0.7775 - val_loss: 0.4616 - val_accuracy: 0.8403
# Epoch 2/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4397 - accuracy: 0.8476 - val_loss: 0.4213 - val_accuracy: 0.8533
# Epoch 3/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3980 - accuracy: 0.8587 - val_loss: 0.3851 - val_accuracy: 0.8666
# Epoch 4/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3661 - accuracy: 0.8682 - val_loss: 0.3692 - val_accuracy: 0.8710
# Epoch 5/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3492 - accuracy: 0.8734 - val_loss: 0.3650 - val_accuracy: 0.8741
# Epoch 6/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3332 - accuracy: 0.8793 - val_loss: 0.3489 - val_accuracy: 0.8745
# Epoch 7/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3170 - accuracy: 0.8852 - val_loss: 0.3393 - val_accuracy: 0.8803
# Epoch 8/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3082 - accuracy: 0.8874 - val_loss: 0.3551 - val_accuracy: 0.8756
# Epoch 9/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2965 - accuracy: 0.8911 - val_loss: 0.3334 - val_accuracy: 0.8824
# Epoch 10/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2897 - accuracy: 0.8941 - val_loss: 0.3290 - val_accuracy: 0.8821
# Epoch 11/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2795 - accuracy: 0.8983 - val_loss: 0.3333 - val_accuracy: 0.8784
# Epoch 12/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2693 - accuracy: 0.9010 - val_loss: 0.3355 - val_accuracy: 0.8799
# Epoch 13/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2680 - accuracy: 0.9023 - val_loss: 0.3176 - val_accuracy: 0.8876
# Epoch 14/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2604 - accuracy: 0.9047 - val_loss: 0.3476 - val_accuracy: 0.8738
# Epoch 15/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2551 - accuracy: 0.9061 - val_loss: 0.3234 - val_accuracy: 0.8854
# Epoch 16/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2486 - accuracy: 0.9081 - val_loss: 0.3178 - val_accuracy: 0.8885
# Epoch 17/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2418 - accuracy: 0.9107 - val_loss: 0.3251 - val_accuracy: 0.8844
# Epoch 18/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2411 - accuracy: 0.9100 - val_loss: 0.3301 - val_accuracy: 0.8843
# Epoch 19/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2334 - accuracy: 0.9125 - val_loss: 0.3265 - val_accuracy: 0.8877
# Epoch 20/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2293 - accuracy: 0.9152 - val_loss: 0.3190 - val_accuracy: 0.8887
# Epoch 21/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2244 - accuracy: 0.9176 - val_loss: 0.3471 - val_accuracy: 0.8827
# Epoch 22/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2201 - accuracy: 0.9182 - val_loss: 0.3446 - val_accuracy: 0.8831
# Epoch 23/30
# 329/329 [==============================] - 2s 5ms/step - loss: 0.2195 - accuracy: 0.9189 - val_loss: 0.3286 - val_accuracy: 0.8886
# Epoch 24/30
# 329/329 [==============================] - 2s 5ms/step - loss: 0.2088 - accuracy: 0.9220 - val_loss: 0.3264 - val_accuracy: 0.8885
# Epoch 25/30
# 329/329 [==============================] - 2s 5ms/step - loss: 0.2058 - accuracy: 0.9238 - val_loss: 0.3436 - val_accuracy: 0.8797
# Epoch 26/30
# 329/329 [==============================] - 2s 5ms/step - loss: 0.2032 - accuracy: 0.9243 - val_loss: 0.3464 - val_accuracy: 0.8841
# Epoch 27/30
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1992 - accuracy: 0.9254 - val_loss: 0.3399 - val_accuracy: 0.8844
# Epoch 28/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1954 - accuracy: 0.9275 - val_loss: 0.3346 - val_accuracy: 0.8900
# Epoch 29/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1901 - accuracy: 0.9300 - val_loss: 0.3330 - val_accuracy: 0.8890
# Epoch 30/30
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1892 - accuracy: 0.9299 - val_loss: 0.3378 - val_accuracy: 0.8898

# %%
import numpy as np
import matplotlib.pyplot as plt

def draw_loss_acc(history_1, history_2, epochs):
    his_dict_1 = history_1.history
    his_dict_2 = history_2.history
    keys = list(his_dict_1.keys())
    
    epochs = range(1, epochs)
    fig = plt.figure(figsize = (10, 10))
    ax = fig.add_subplot(1, 1, 1)
    # axis 선과 ax의 축 레이블을 제거합니다.
    ax.spines['top'].set_color('none')
    ax.spines['bottom'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['right'].set_color('none')
    ax.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)
    for i in range(len(his_dict_1)):
        temp_ax = fig.add_subplot(2, 2, i + 1)
        temp = keys[i%2]
        val_temp = keys[(i + 2)%2 + 2]
        temp_history = his_dict_1 if i < 2 else his_dict_2
        temp_ax.plot(epochs, temp_history[temp][1:], 
                     color = 'blue', label = 'train_' + temp)
        temp_ax.plot(epochs, temp_history[val_temp][1:], 
                     color = 'orange', label = val_temp)
        if(i == 1 or i == 3):
            start, end = temp_ax.get_ylim()
            temp_ax.yaxis.set_ticks(np.arange(np.round(start, 2), end, 0.01))
        temp_ax.legend()
    ax.set_ylabel('loss', size = 20)
    ax.set_xlabel('Epochs', size = 20)
    plt.tight_layout()
    plt.show()
    
draw_loss_acc(first_history, second_history, 30)

# %% [markdown]
# 모델 평가하기

# %%
print(first_model.evaluate(y_test,result))
print(second_model.evaluate(y_test,result))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-cbc5bda168eb> in <module>()
# ----> 1 print(first_model.evaluate(y_test,result))
#       2 print(second_model.evaluate(y_test,result))
#
# NameError: name 'result' is not defined

# %%
import numpy as np

results = first_model.predict(x_test)
np.set_printoptions(precision=7) # numpy 소수점 제한

arg_results = np.argmax(results, axis = -1) # 가장 큰 값의 인덱스를 가져옵니다.

import matplotlib.pyplot as plt

sample_size = 10
# 0 ~ 9999의 범위에서 무작위로 정수를 뽑습니다.
random_idx = np.random.randint(10000) 

plt.figure(figsize = (5, 5))
plt.imshow(x_test[random_idx], cmap = 'gray')
plt.title('Predicted value of the image : ' 
          + class_names[arg_results[random_idx]] 
          + ', Real Value of the image: '+class_names[real_y_test[random_idx]])
plt.show()
