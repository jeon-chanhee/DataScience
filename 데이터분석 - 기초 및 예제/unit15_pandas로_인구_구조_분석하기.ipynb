# %% [markdown]
# 문제 정의 : 전국에서 신림동의 연령별 인구 구조와 가장 형태가 비슷한 지역은 어디 일까?

# %% [markdown]
# 한글깨짐 방지

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %% [markdown]
# 1. 데이터 읽어오

# %%
import pandas as pd

df = pd.read_csv('age.csv',encoding='cp949',index_col=0)  # 0번째 인덱스 column으로 설정
df.head()
# Out:
#                                 총인구수  ...  2019년02월_계_100세 이상
# 행정구역                                  ...
# 서울특별시  (1100000000)          9770638  ...                5932
# 서울특별시 종로구 (1111000000)        152880  ...                 236
# 서울특별시 종로구 청운효자동(1111051500)    13010  ...                  16
# 서울특별시 종로구 사직동(1111053000)       9584  ...                  17
# 서울특별시 종로구 삼청동(1111054000)       2820  ...                   7
#
# [5 rows x 103 columns]

# %%
df.info()  # 데이터 형태 꼭 확인하기
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3841 entries, 서울특별시  (1100000000) to 제주특별자치도 서귀포시 예래동(5013062000)
# Columns: 103 entries, 총인구수 to 2019년02월_계_100세 이상
# dtypes: int64(103)
# memory usage: 3.0+ MB

# %% [markdown]
# 인구수 -> 인구비율로 데이터 전처리

# %%
df.head()
# Out:
#                                 총인구수  ...  2019년02월_계_100세 이상
# 행정구역                                  ...
# 서울특별시  (1100000000)          9770638  ...                5932
# 서울특별시 종로구 (1111000000)        152880  ...                 236
# 서울특별시 종로구 청운효자동(1111051500)    13010  ...                  16
# 서울특별시 종로구 사직동(1111053000)       9584  ...                  17
# 서울특별시 종로구 삼청동(1111054000)       2820  ...                   7
#
# [5 rows x 103 columns]

# %%
df = df.div(df['총인구수'],axis=0)  # df.div = 전체 데이터를 '총 인구수'로 나눔 -> 비율로 변환시키는 작업
df.head()                            # axis=0 은 행으로 1줄씩 실행시키겠다는 뜻
# Out:
#                              총인구수  연령구간인구수  ...  2019년02월_계_99세  2019년02월_계_100세 이상
# 행정구역                                        ...
# 서울특별시  (1100000000)           1.0      1.0  ...        0.000090            0.000607
# 서울특별시 종로구 (1111000000)        1.0      1.0  ...        0.000255            0.001544
# 서울특별시 종로구 청운효자동(1111051500)   1.0      1.0  ...        0.000154            0.001230
# 서울특별시 종로구 사직동(1111053000)     1.0      1.0  ...        0.000417            0.001774
# 서울특별시 종로구 삼청동(1111054000)     1.0      1.0  ...        0.000709            0.002482
#
# [5 rows x 103 columns]

# %%
del df['총인구수'], df['연령구간인구수'] # 총인구수, 연령구간이구수열 삭제
df.head()
# Out:
#                              2019년02월_계_0세  ...  2019년02월_계_100세 이상
# 행정구역                                        ...
# 서울특별시  (1100000000)               0.005500  ...            0.000607
# 서울특별시 종로구 (1111000000)            0.003879  ...            0.001544
# 서울특별시 종로구 청운효자동(1111051500)       0.005073  ...            0.001230
# 서울특별시 종로구 사직동(1111053000)         0.004487  ...            0.001774
# 서울특별시 종로구 삼청동(1111054000)         0.003191  ...            0.002482
#
# [5 rows x 101 columns]

# %% [markdown]
# 2~3. 궁금한 지역 이름 받고 해당 지역의 인구 구조 저장하기

# %%
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
a = df.index.str.contains(name) # 해당 행의 인덱스를 찾아서 인구 구조를 저장

df2 = df[a]
df2.head()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 서울특별시
#                              2019년02월_계_0세  ...  2019년02월_계_100세 이상
# 행정구역                                        ...
# 서울특별시  (1100000000)               0.005500  ...            0.000607
# 서울특별시 종로구 (1111000000)            0.003879  ...            0.001544
# 서울특별시 종로구 청운효자동(1111051500)       0.005073  ...            0.001230
# 서울특별시 종로구 사직동(1111053000)         0.004487  ...            0.001774
# 서울특별시 종로구 삼청동(1111054000)         0.003191  ...            0.002482
#
# [5 rows x 101 columns]

# %% [markdown]
# 궁금한 지역 인구구조 시각화

# %%
df2.T # 행을 열로 바꿔주는 함수
# Out:
# 행정구역                서울특별시 구로구 신도림동(1153051000)
# 2019년02월_계_0세                         0.008747
# 2019년02월_계_1세                         0.008962
# 2019년02월_계_2세                         0.010894
# 2019년02월_계_3세                         0.011082
# 2019년02월_계_4세                         0.010438
# ...                                        ...
# 2019년02월_계_96세                        0.000134
# 2019년02월_계_97세                        0.000107
# 2019년02월_계_98세                        0.000054
# 2019년02월_계_99세                        0.000080
# 2019년02월_계_100세 이상                    0.000188
#
# [101 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

# 데이터 시각화

plt.rcParams['figure.figsize'] = (10,4)
plt.rcParams['figure.dpi'] = 200
plt.style.use('ggplot')
df2.T.plot()
plt.show()

# %%
df2.iloc[0]
# Out:
# 2019년02월_계_0세         0.008747
# 2019년02월_계_1세         0.008962
# 2019년02월_계_2세         0.010894
# 2019년02월_계_3세         0.011082
# 2019년02월_계_4세         0.010438
#                         ...
# 2019년02월_계_96세        0.000134
# 2019년02월_계_97세        0.000107
# 2019년02월_계_98세        0.000054
# 2019년02월_계_99세        0.000080
# 2019년02월_계_100세 이상    0.000188
# Name: 서울특별시 구로구 신도림동(1153051000), Length: 101, dtype: float64

# %%
df.sub(df2.iloc[0],axis=1)    # home-away sub는 빼기 함수 열을 기준으로 빼서 axis=1
# Out:
#                               2019년02월_계_0세  ...  2019년02월_계_100세 이상
# 행정구역                                         ...
# 서울특별시  (1100000000)               -0.003248  ...            0.000419
# 서울특별시 종로구 (1111000000)            -0.004869  ...            0.001356
# 서울특별시 종로구 청운효자동(1111051500)       -0.003674  ...            0.001042
# 서울특별시 종로구 사직동(1111053000)         -0.004261  ...            0.001586
# 서울특별시 종로구 삼청동(1111054000)         -0.005556  ...            0.002294
# ...                                     ...  ...                 ...
# 제주특별자치도 서귀포시 서홍동(5013058000)      -0.001319  ...            0.000003
# 제주특별자치도 서귀포시 대륜동(5013059000)       0.000505  ...            0.000233
# 제주특별자치도 서귀포시 대천동(5013060000)      -0.000152  ...           -0.000041
# 제주특별자치도 서귀포시 중문동(5013061000)      -0.002367  ...            0.000351
# 제주특별자치도 서귀포시 예래동(5013062000)      -0.000265  ...            0.001024
#
# [3841 rows x 101 columns]

# %%
df.loc[df.sub(df2.iloc[0],axis=1).sum(axis=1).sort_values().index[:5]]   # 1을 기준 즉, 열을 방향으로 해서 더해라
                                                  # 왜 axis=1 ? 데이터가 행을 기준으로 정렬되었기 때문에
                                                   # sum 해주는 이유 -> 모든 차이를 더해서 하나의 데이터로 비교를 하기 위해
                                                   # 오름차순으로 정리, 5개까지 뽑아라
# Out:
#                                 2019년02월_계_0세  ...  2019년02월_계_100세 이상
# 행정구역                                           ...
# 전라남도 신안군 압해읍고이도출장소(4691025500)       0.000000  ...            0.000000
# 경상남도 진주시 대평면(4817045000)             0.001712  ...            0.001712
# 경상남도 합천군 덕곡면(4889038000)             0.003505  ...            0.000000
# 경상북도 구미시 무을면(4719031000)             0.001522  ...            0.001522
# 충청남도 서천군 판교면(4477038000)             0.001345  ...            0.000896
#
# [5 rows x 101 columns]

# %%
import numpy as np
df.loc[np.power(df.sub(df2.iloc[0],axis=1),2).sum(axis=1).sort_values().index[:5]].T.plot()
# np.power(df.sub(df2.iloc[0],axis=1),2) 음수를 없애기 위해 제곱 -> 2 대입
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


plt.rcParams['figure.figsize'] = (10, 4)
plt.rcParams['figure.dpi'] = 200
plt.style.use('ggplot')

#데이터 가져오기
df = pd.read_csv('age.csv',encoding='cp949', index_col=0)

# 전체 데이터를 총 인구수로 나눠서 비율로 변환
df = df.div(df['총인구수'],axis=0)

# 필요 없는 컬럼 제거
del df['총인구수'], df['연령구간인구수']

# 지역 이름 입력
name = input('원하는 지역의 이름을 입력해주세요 : ')

# 해당 행을 찾아서 해당 지역의 인구 구조를 저장
a = df.index.str.contains(name)
df2 = df[a] #인구 구조를 저장

# 인구 구조가 같은 지역 찾아 지도 시각화 TOP 5 (자기 자신 제외)
df.loc[np.power(df.sub(df2.iloc[0], axis =1), 2).sum(axis = 1).sort_values().index[1:6]].T.plot()
plt.show()
# Out:
# 원하는 지역의 이름을 입력해주세요 : 신도림동
